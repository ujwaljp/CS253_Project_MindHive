# %%
from bs4 import BeautifulSoup
import re
import requests
# conn = sqlite3.connect('../database/students.db')
# c = conn.cursor()

s = requests.Session()
s.get("https://oa.cc.iitk.ac.in/Oa/Jsp/Main_Frameset.jsp")
s.get("https://oa.cc.iitk.ac.in/Oa/Jsp/Main_Intro.jsp?frm='SRCH'")
s.get("https://oa.cc.iitk.ac.in/Oa/Jsp/OAServices/IITK_Srch.jsp?typ=stud")

headers = {
    "Referer": "https://oa.cc.iitk.ac.in/Oa/Jsp/OAServices/IITK_Srch.jsp?typ=stud"
}

headers1 = {
    "Referer": "https://oa.cc.iitk.ac.in/Oa/Jsp/OAServices/IITk_SrchStudRoll_new.jsp"
}

# %%
payload = {
    'k4': 'oa',
    'numtxt': '',
    'recpos': 0,
    'str': '',
    'selstudrol': '',
    'selstuddep': '',
    'selstudnam': '',
    'txrollno': '',
    'Dept_Stud': '',
    'selnam1': '',
    'mail': ''
}

payload1 = {
    'typ': ['stud'],
    'numtxt': '',
    'sbm': ['Y']
}

TOTAL = 8385

# %%
def process_response_soup(soup):
    for link in soup.select('.TableText a'):
        print(link)
        print(soup)
        print("-----------------------")
        roll = link.get_text().strip()
        print(roll)
        payload1['numtxt'] = roll
        r1 = s.post("https://oa.cc.iitk.ac.in/Oa/Jsp/OAServices/IITk_SrchRes_new.jsp", headers=headers1, data=payload1)
        soup1 = BeautifulSoup(r1.text, 'html.parser')

        print(soup1)
        name = ''
        program = ''
        dept = ''
        hall = ''
        room = ''
        username = ''
        blood_group = ''
        gender = ''
        hometown = ''

        # for para in soup1.select('.TableContent p'):
        #     body = para.get_text().strip()
        #     field = body.split(':')
        #     key = field[0].strip()
        #     value = field[1].strip()
        #     if key == 'Name':
        #         name = value.lower().title()
        #     elif key == 'Program':
        #         program = value
        #     elif key == 'Department':
        #         dept = value.lower().title()
        #     elif key == 'Hostel Info':
        #         if len(value.split(',')) > 1:
        #             hall = value.split(',')[0].strip()
        #             room = value.split(',')[1].strip()
        #     elif key == 'E-Mail':
        #         if len(value.split('@')) > 1:
        #             username = value.split('@')[0].strip()
        #     elif key == 'Blood Group':
        #         blood_group = value
        #     elif key == 'Gender':
        #         if len(value.split('\t')) > 1:
        #             gender = value.split('\t')[0].strip()
        #     else:
        #         print("{} {}".format(key, value))

        # body = soup1.prettify()
        # if len(body.split('Permanent Address :')) > 1:
        #     address = body.split('Permanent Address :')[1].split(',')
        #     if len(address) > 2:
        #         address = address[len(address) - 3: len(address) - 1]
        #         hometown = "{}, {}".format(address[0], address[1])

        # print(roll) 
        # print(username)
        # print(name) 
        # print(program)
        # print(dept) 
        # print(hall) 
        # print(room)
        # print(blood_group)
        # print(gender)
        # print(hometown)

# %%
# for i in range(12, TOTAL+1, 12):
payload['mail'] = 'adips20'
r = s.post("https://oa.cc.iitk.ac.in/Oa/Jsp/OAServices/IITk_SrchStudRoll_new.jsp", headers=headers, data=payload)
soup = BeautifulSoup(r.text, 'html.parser')
process_response_soup(soup)
# print("Processed {}".format(i + 12))
    # conn.commit()
# conn.close()
# Out:
# <a href="javascript:searchres('10017');">10017
# 						</a>
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Oracle JDeveloper" name="GENERATOR"/>
# <meta content="no-cache" http-equiv="cache-control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <link href="oasback.css" rel="Stylesheet" type="text/css"/>
# <title>Search_name</title>
# </head>
# <script language="javascript" type="text/javascript">
#
#  var message="";
# 			function clickIE()
# 			{
# 				if (document.all) {alert(message);return false;}
# 			}
# 			function clickNS(e)
# 			{
# 				if (document.layers||(document.getElementById&&!document.all))
# 				{
# 				  	if (e.which==2||e.which==3)
# 				  		{
# 				  			// alert(message);
# 				  			return false;
# 				  		}
# 				}
# 			}
# 				  	if (document.layers)
# 				  	{document.captureEvents(Event.MOUSEDOWN);document.onmousedown=clickNS;}
# 				  	else{document.onmouseup=clickNS;document.oncontextmenu=clickIE;}
# 			  	document.oncontextmenu=new Function("return false")
#
#
#   var s1;
#
#
#   function IsEmptyString(str)
# {
# 	nLen = str.length;
# 	for(i=0; i<nLen; ++i)
# 	{
# 		if(str.charAt(i) != " ")
# 		{
# 			return false;
# 		}
# 	}
# 	return true;
# }
#
#
# function next()
# {
#
# document.Srchfrm1.submit();
#
# }
#
# function prev(val)
# {
#
# document.Srchfrm1.recpos.value=val;
# document.Srchfrm1.submit();
# }
#
# function searchres(x){
#
#  document.Srchfrm1.numtxt.value=x;
# document.Srchfrm1.action="IITk_SrchRes_new.jsp";
# document.Srchfrm1.method="POST";
# document.Srchfrm1.submit();
#
# }
#
# </script>
# <body leftmargin="0" marginheight="0" marginwidth="0" topmargin="0">
# <p>
#
# 		</p>
# <form action="IITk_SrchStudRoll_new.jsp" method="post" name="Srchfrm1">
# <input name="k1" type="hidden" value="#ADELukNhHiN=H!_@/JyAGZyZaIWB$juKblR&amp;KFEtBFWNSo%p-#OTCX"/>
# <input name="k2" type="hidden" value="Jp=IE&amp;CFHUp_UOIXYaPQhmTCH_U/xz&amp;u@fZoiPraG-YuUEsoEBGVr$S"/>
# <input name="k3" type="hidden" value="gnYJd#NsOd-WphfNDrZ_FVDEAFGew!nRBih$@WDLSEhTXVJeHjLBSuI"/>
# <input name="numtxt" type="hidden" value="">
# <table align="center" border="0" width="100%">
# <tr>
# <td align="center" class="tablehead">
# 						Student Search
# 					</td>
# </tr>
# </table>
# <br/>
# <div align="left" class="DivContent">
#
# 				You are viewing
# 				<b>1 </b> to
# 				<b>12 </b> records out of
# 				<b>12669 </b> records
#
#
# 			</div>
# <br/>
# <table border="0" cellpadding="1" cellspacing="1" width="100%">
# <tr bgcolor="darkblue">
# <th align="left" class="TableHead">
# 						Rollno
# 					</th>
# <th align="left" class="TableHead">
# 						Name
# 					</th>
# <th align="left" class="TableHead">
# 						Department
# 					</th>
# <th align="left" class="TableHead">
# 						Program
# 					</th>
# <th align="left" class="TableHead">
# 						Blood Group
# 					</th>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud">
# <input name="sbm" type="hidden" value="Y">
# <a href="javascript:searchres('10017');">10017
# 						</a>
# </input></input></td>
# <td class="TableText">
# 						ABHISHEK ANAND YADAV
# 					</td>
# <td class="TableText">
# 						PHYSICS
# 					</td>
# <td class="TableText">
# 						MSc(Int)
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10029');">10029
# 						</a>
# </td>
# <td class="TableText">
# 						ABHISHEK PRASAD SAHOO
# 					</td>
# <td class="TableText">
# 						MATERIALS SCIENCE &amp; ENGG.
# 					</td>
# <td class="TableText">
# 						BTech
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10032');">10032
# 						</a>
# </td>
# <td class="TableText">
# 						ABHISHEK S SAYAM
# 					</td>
# <td class="TableText">
# 						COMPUTER SCIENCE &amp; ENGG.
# 					</td>
# <td class="TableText">
# 						MT(Dual)
# 					</td>
# <td class="TableText">
# 						B+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10047');">10047
# 						</a>
# </td>
# <td class="TableText">
# 						AJIT KUMAR
# 					</td>
# <td class="TableText">
# 						CIVIL ENGG.
# 					</td>
# <td class="TableText">
# 						BTech
# 					</td>
# <td class="TableText">
# 						B+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10053');">10053
# 						</a>
# </td>
# <td class="TableText">
# 						AKASH  KUMAR
# 					</td>
# <td class="TableText">
# 						CIVIL ENGG.
# 					</td>
# <td class="TableText">
# 						MT(Dual)
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10088');">10088
# 						</a>
# </td>
# <td class="TableText">
# 						ANIL  KUMAR
# 					</td>
# <td class="TableText">
# 						ELECTRICAL ENGG.
# 					</td>
# <td class="TableText">
# 						BTech
# 					</td>
# <td class="TableText">
# 						AB+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10100063');">10100063
# 						</a>
# </td>
# <td class="TableText">
# 						TARUSHIKHA  SARVESH
# 					</td>
# <td class="TableText">
# 						HUMANITIES &amp; SOC. SCIENCES
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						B+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10101061');">10101061
# 						</a>
# </td>
# <td class="TableText">
# 						ANSHUL  KHANDELWAL
# 					</td>
# <td class="TableText">
# 						AEROSPACE ENGG.
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10101065');">10101065
# 						</a>
# </td>
# <td class="TableText">
# 						SUNIL  KUMAR
# 					</td>
# <td class="TableText">
# 						AEROSPACE ENGG.
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10101066');">10101066
# 						</a>
# </td>
# <td class="TableText">
# 						DAVINDER SINGH BHOGAL
# 					</td>
# <td class="TableText">
# 						AEROSPACE ENGG.
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10102043');">10102043
# 						</a>
# </td>
# <td class="TableText">
# 						VINOD DIGAMBAR DAHAKE
# 					</td>
# <td class="TableText">
# 						CHEMICAL ENGG.
# 					</td>
# <td class="TableText">
# 						MTech
# 					</td>
# <td class="TableText">
# 						AB+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10103003');">10103003
# 						</a>
# </td>
# <td class="TableText">
# 						ARTI  KUMARI
# 					</td>
# <td class="TableText">
# 						CIVIL ENGG.
# 					</td>
# <td class="TableText">
# 						MTech
# 					</td>
# <td class="TableText">
# 						A+
# 					</td>
# </tr>
# </table>
# <table align="right">
# <tr>
# <td>
# <input id="recpos" name="recpos" type="hidden" value="12"/>
# <input name="selstudrol" type="hidden" value=""/>
# <input name="selstuddep" type="hidden" value=""/>
# <input name="selstudnam" type="hidden" value=""/>
# <!--<font color="Darkmagenta" size=2  style="cursor:hand;" title="Next"><b>-->
# <a href="javascript:next()">NEXT</a><b></b>
# </td>
# </tr>
# </table>
# </input></form>
# </body>
# </html>
#
# -----------------------
# 10017
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Oracle JDeveloper" name="GENERATOR"/>
# <title>Search -IITK</title>
# <link href="oasback.css" rel="Stylesheet" type="text/css"/>
# <script language="JavaScript" type="text/javascript">
#  var message="";
# 			function clickIE()
# 			{
# 				if (document.all) {alert(message);return false;}
# 			}
# 			function clickNS(e)
# 			{
# 				if (document.layers||(document.getElementById&&!document.all))
# 				{
# 				  	if (e.which==2||e.which==3)
# 				  		{
# 				  			// alert(message);
# 				  			return false;
# 				  		}
# 				}
# 			}
# 				  	if (document.layers)
# 				  	{document.captureEvents(Event.MOUSEDOWN);document.onmousedown=clickNS;}
# 				  	else{document.onmouseup=clickNS;document.oncontextmenu=clickIE;}
# 			  	document.oncontextmenu=new Function("return false")
#
#
# function frmsbm()
# {
# 	var x;
# 	x = 0;
# 	if(IsEmptyString(document.srchfrm.numtxt.value))
# 	{
# 		alert("Please enter Pfno/RollNo to search");
# 		document.srchfrm.numtxt.focus();
# 		x=x+1;
# 		return false;
# 	}
#   if(x==0)
#   {
#     document.srchfrm.method = "post";
# 		document.srchfrm.action= "IITk_SrchRes_new.jsp?sbm=Y";
# 		document.srchfrm.submit();
# 	}
# 	return true;
# }
#
#
# function IsEmptyString(str)
# {
# 	nLen = str.length;
# 	for(i=0; i<nLen; ++i)
# 	{
# 		if(str.charAt(i) != " ")
# 		{
# 			return false;
# 		}
# 	}
# 	return true;
# }
#
# function backfn()
# {
# if (document.srchfrm.bk.value=="Y")
# {
#  document.srchfrm.method="post";
#  document.srchfrm.action="IITK_Srch.jsp?typ=stud";
#  document.srchfrm.submit();
# }
# else
# window.history.go(-1);
# }
#
# </script>
# </head>
# <body bgcolor="lightsteelblue" leftmargin="20" marginheight="0" marginwidth="0" onload="document.srchfrm.numtxt.focus();" text="#000000" topmargin="0">
# <br/>
# <form action="" method="get" name="srchfrm" onsubmit="frmsbm();">
# <input name="typ" type="hidden" value="stud"/>
# <input name="bk" type="hidden" value=""/>
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="center" valign="top">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td align="left" valign="top">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td>
# <img alt="" height="10" src="images/transparent.gif" width="1"/>
# </td>
# </tr>
# <tr></tr>
# <tr>
# <td>
# <table border="0" cellpadding="2" cellspacing="0">
# <tr class="TableContent">
# </tr></table></td>
# <td height="20">
# <b>Enter Student RollNo:</b>
# </td>
# <td class="menu1" height="20" nowrap="nowrap">
# <input name="numtxt" size="15" type="text"/>
#
# 															<input class="submit_button" name="sbmbtn" onclick="frmsbm();" title="NEW" type="button" value="Submit"/>
# </td>
# </tr>
# <tr>
# <td height="20"></td>
# </tr>
# </table>
# <br/>
# <div align="center">
# <center>
# <table border="0" cellpadding="2" cellspacing="2" width="100%">
# <tr>
# <td align="right" valign="top" width="25%">
# <img alt="" height="130" src="https://oa.cc.iitk.ac.in:443/Oa/Jsp/Photo/10017_0.jpg" width="130"/>
# </td>
# <td class="TableContent" nowrap="nowrap" valign="top" width="55%">
# <b>Roll No: </b>
# 																	10017
# 																	<br/>
# <br/>
# <p>
# <b>Name: </b>
# 																		ABHISHEK ANAND YADAV
# 																	</p>
# <p>
# <b>Program: </b>
# 																		MSc(Int)
# 																	</p>
# <p>
# <b>Department: </b>
# 																		PHYSICS
# 																	</p>
# <p>
# <b>Hostel Info: </b>
# 																		HALL3, 326
# 																		<br/>
# </p>
# <p>
# <b> E-Mail: </b><a href="mailto:abhiy@iitk.ac.in">abhiy@iitk.ac.in
# 																		</a>
# </p>
# <p>
# <b> Blood Group:</b>
# 																		O+
# 																		<!--<b> Category:</b>OB<br></P>-->
# </p>
# <p>
# <b> Gender:</b>
# 																		M
# 																		<b> CountryOfOrigin:</b>
# 																		India
# 																		<br/>
# </p>
# <!--<p><b>Local Address :</b>Naresh Verma<br>near laxmi hospital kalyanpur,Kanpur,U.P.,India<br>
# 		Phone no:Not Available<br>Mobile no:Not Available</P>
# 		<p><b>Permanent Address :</b>R M yadav<br>P 52 Vimal Kunj picnic spot road,indira nagar,Lucknow,U.P.,India<br>
#   		Phone no:09336226006<br>Mobile no:09125460484</P>
#                 <p><a href="Stff_Addr.jsp?typ=stud&pfno=10017">Address</a></p>-->
# </td>
# </tr>
# </table>
# <font></font>
# </center>
# </div>
# </td>
# <td></td>
# </tr>
# </table>
# <br/>
# </td>
# </tr>
# </table>
#
#
#
# <center>
# <br/>
# <br/>
# <br/>
# <table border="0" cellpadding="2" cellspacing="0">
# <tr>
# <td colspan="10">
# <input class="submit_button" name="sbmbtn1" onclick="backfn();" type="button" value="Back"/>
# </td>
# </tr>
# </table>
# </center>
# </form>
# </body>
# </html>
#
# <a href="javascript:searchres('10029');">10029
# 						</a>
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Oracle JDeveloper" name="GENERATOR"/>
# <meta content="no-cache" http-equiv="cache-control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <link href="oasback.css" rel="Stylesheet" type="text/css"/>
# <title>Search_name</title>
# </head>
# <script language="javascript" type="text/javascript">
#
#  var message="";
# 			function clickIE()
# 			{
# 				if (document.all) {alert(message);return false;}
# 			}
# 			function clickNS(e)
# 			{
# 				if (document.layers||(document.getElementById&&!document.all))
# 				{
# 				  	if (e.which==2||e.which==3)
# 				  		{
# 				  			// alert(message);
# 				  			return false;
# 				  		}
# 				}
# 			}
# 				  	if (document.layers)
# 				  	{document.captureEvents(Event.MOUSEDOWN);document.onmousedown=clickNS;}
# 				  	else{document.onmouseup=clickNS;document.oncontextmenu=clickIE;}
# 			  	document.oncontextmenu=new Function("return false")
#
#
#   var s1;
#
#
#   function IsEmptyString(str)
# {
# 	nLen = str.length;
# 	for(i=0; i<nLen; ++i)
# 	{
# 		if(str.charAt(i) != " ")
# 		{
# 			return false;
# 		}
# 	}
# 	return true;
# }
#
#
# function next()
# {
#
# document.Srchfrm1.submit();
#
# }
#
# function prev(val)
# {
#
# document.Srchfrm1.recpos.value=val;
# document.Srchfrm1.submit();
# }
#
# function searchres(x){
#
#  document.Srchfrm1.numtxt.value=x;
# document.Srchfrm1.action="IITk_SrchRes_new.jsp";
# document.Srchfrm1.method="POST";
# document.Srchfrm1.submit();
#
# }
#
# </script>
# <body leftmargin="0" marginheight="0" marginwidth="0" topmargin="0">
# <p>
#
# 		</p>
# <form action="IITk_SrchStudRoll_new.jsp" method="post" name="Srchfrm1">
# <input name="k1" type="hidden" value="#ADELukNhHiN=H!_@/JyAGZyZaIWB$juKblR&amp;KFEtBFWNSo%p-#OTCX"/>
# <input name="k2" type="hidden" value="Jp=IE&amp;CFHUp_UOIXYaPQhmTCH_U/xz&amp;u@fZoiPraG-YuUEsoEBGVr$S"/>
# <input name="k3" type="hidden" value="gnYJd#NsOd-WphfNDrZ_FVDEAFGew!nRBih$@WDLSEhTXVJeHjLBSuI"/>
# <input name="numtxt" type="hidden" value="">
# <table align="center" border="0" width="100%">
# <tr>
# <td align="center" class="tablehead">
# 						Student Search
# 					</td>
# </tr>
# </table>
# <br/>
# <div align="left" class="DivContent">
#
# 				You are viewing
# 				<b>1 </b> to
# 				<b>12 </b> records out of
# 				<b>12669 </b> records
#
#
# 			</div>
# <br/>
# <table border="0" cellpadding="1" cellspacing="1" width="100%">
# <tr bgcolor="darkblue">
# <th align="left" class="TableHead">
# 						Rollno
# 					</th>
# <th align="left" class="TableHead">
# 						Name
# 					</th>
# <th align="left" class="TableHead">
# 						Department
# 					</th>
# <th align="left" class="TableHead">
# 						Program
# 					</th>
# <th align="left" class="TableHead">
# 						Blood Group
# 					</th>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud">
# <input name="sbm" type="hidden" value="Y">
# <a href="javascript:searchres('10017');">10017
# 						</a>
# </input></input></td>
# <td class="TableText">
# 						ABHISHEK ANAND YADAV
# 					</td>
# <td class="TableText">
# 						PHYSICS
# 					</td>
# <td class="TableText">
# 						MSc(Int)
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10029');">10029
# 						</a>
# </td>
# <td class="TableText">
# 						ABHISHEK PRASAD SAHOO
# 					</td>
# <td class="TableText">
# 						MATERIALS SCIENCE &amp; ENGG.
# 					</td>
# <td class="TableText">
# 						BTech
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10032');">10032
# 						</a>
# </td>
# <td class="TableText">
# 						ABHISHEK S SAYAM
# 					</td>
# <td class="TableText">
# 						COMPUTER SCIENCE &amp; ENGG.
# 					</td>
# <td class="TableText">
# 						MT(Dual)
# 					</td>
# <td class="TableText">
# 						B+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10047');">10047
# 						</a>
# </td>
# <td class="TableText">
# 						AJIT KUMAR
# 					</td>
# <td class="TableText">
# 						CIVIL ENGG.
# 					</td>
# <td class="TableText">
# 						BTech
# 					</td>
# <td class="TableText">
# 						B+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10053');">10053
# 						</a>
# </td>
# <td class="TableText">
# 						AKASH  KUMAR
# 					</td>
# <td class="TableText">
# 						CIVIL ENGG.
# 					</td>
# <td class="TableText">
# 						MT(Dual)
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10088');">10088
# 						</a>
# </td>
# <td class="TableText">
# 						ANIL  KUMAR
# 					</td>
# <td class="TableText">
# 						ELECTRICAL ENGG.
# 					</td>
# <td class="TableText">
# 						BTech
# 					</td>
# <td class="TableText">
# 						AB+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10100063');">10100063
# 						</a>
# </td>
# <td class="TableText">
# 						TARUSHIKHA  SARVESH
# 					</td>
# <td class="TableText">
# 						HUMANITIES &amp; SOC. SCIENCES
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						B+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10101061');">10101061
# 						</a>
# </td>
# <td class="TableText">
# 						ANSHUL  KHANDELWAL
# 					</td>
# <td class="TableText">
# 						AEROSPACE ENGG.
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10101065');">10101065
# 						</a>
# </td>
# <td class="TableText">
# 						SUNIL  KUMAR
# 					</td>
# <td class="TableText">
# 						AEROSPACE ENGG.
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10101066');">10101066
# 						</a>
# </td>
# <td class="TableText">
# 						DAVINDER SINGH BHOGAL
# 					</td>
# <td class="TableText">
# 						AEROSPACE ENGG.
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10102043');">10102043
# 						</a>
# </td>
# <td class="TableText">
# 						VINOD DIGAMBAR DAHAKE
# 					</td>
# <td class="TableText">
# 						CHEMICAL ENGG.
# 					</td>
# <td class="TableText">
# 						MTech
# 					</td>
# <td class="TableText">
# 						AB+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10103003');">10103003
# 						</a>
# </td>
# <td class="TableText">
# 						ARTI  KUMARI
# 					</td>
# <td class="TableText">
# 						CIVIL ENGG.
# 					</td>
# <td class="TableText">
# 						MTech
# 					</td>
# <td class="TableText">
# 						A+
# 					</td>
# </tr>
# </table>
# <table align="right">
# <tr>
# <td>
# <input id="recpos" name="recpos" type="hidden" value="12"/>
# <input name="selstudrol" type="hidden" value=""/>
# <input name="selstuddep" type="hidden" value=""/>
# <input name="selstudnam" type="hidden" value=""/>
# <!--<font color="Darkmagenta" size=2  style="cursor:hand;" title="Next"><b>-->
# <a href="javascript:next()">NEXT</a><b></b>
# </td>
# </tr>
# </table>
# </input></form>
# </body>
# </html>
#
# -----------------------
# 10029
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Oracle JDeveloper" name="GENERATOR"/>
# <title>Search -IITK</title>
# <link href="oasback.css" rel="Stylesheet" type="text/css"/>
# <script language="JavaScript" type="text/javascript">
#  var message="";
# 			function clickIE()
# 			{
# 				if (document.all) {alert(message);return false;}
# 			}
# 			function clickNS(e)
# 			{
# 				if (document.layers||(document.getElementById&&!document.all))
# 				{
# 				  	if (e.which==2||e.which==3)
# 				  		{
# 				  			// alert(message);
# 				  			return false;
# 				  		}
# 				}
# 			}
# 				  	if (document.layers)
# 				  	{document.captureEvents(Event.MOUSEDOWN);document.onmousedown=clickNS;}
# 				  	else{document.onmouseup=clickNS;document.oncontextmenu=clickIE;}
# 			  	document.oncontextmenu=new Function("return false")
#
#
# function frmsbm()
# {
# 	var x;
# 	x = 0;
# 	if(IsEmptyString(document.srchfrm.numtxt.value))
# 	{
# 		alert("Please enter Pfno/RollNo to search");
# 		document.srchfrm.numtxt.focus();
# 		x=x+1;
# 		return false;
# 	}
#   if(x==0)
#   {
#     document.srchfrm.method = "post";
# 		document.srchfrm.action= "IITk_SrchRes_new.jsp?sbm=Y";
# 		document.srchfrm.submit();
# 	}
# 	return true;
# }
#
#
# function IsEmptyString(str)
# {
# 	nLen = str.length;
# 	for(i=0; i<nLen; ++i)
# 	{
# 		if(str.charAt(i) != " ")
# 		{
# 			return false;
# 		}
# 	}
# 	return true;
# }
#
# function backfn()
# {
# if (document.srchfrm.bk.value=="Y")
# {
#  document.srchfrm.method="post";
#  document.srchfrm.action="IITK_Srch.jsp?typ=stud";
#  document.srchfrm.submit();
# }
# else
# window.history.go(-1);
# }
#
# </script>
# </head>
# <body bgcolor="lightsteelblue" leftmargin="20" marginheight="0" marginwidth="0" onload="document.srchfrm.numtxt.focus();" text="#000000" topmargin="0">
# <br/>
# <form action="" method="get" name="srchfrm" onsubmit="frmsbm();">
# <input name="typ" type="hidden" value="stud"/>
# <input name="bk" type="hidden" value=""/>
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="center" valign="top">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td align="left" valign="top">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td>
# <img alt="" height="10" src="images/transparent.gif" width="1"/>
# </td>
# </tr>
# <tr></tr>
# <tr>
# <td>
# <table border="0" cellpadding="2" cellspacing="0">
# <tr class="TableContent">
# </tr></table></td>
# <td height="20">
# <b>Enter Student RollNo:</b>
# </td>
# <td class="menu1" height="20" nowrap="nowrap">
# <input name="numtxt" size="15" type="text"/>
#
# 															<input class="submit_button" name="sbmbtn" onclick="frmsbm();" title="NEW" type="button" value="Submit"/>
# </td>
# </tr>
# <tr>
# <td height="20"></td>
# </tr>
# </table>
# <br/>
# <div align="center">
# <center>
# <table border="0" cellpadding="2" cellspacing="2" width="100%">
# <tr>
# <td align="right" valign="top" width="25%">
# <img alt="" height="130" src="https://oa.cc.iitk.ac.in:443/Oa/Jsp/Photo/10029_0.jpg" width="130"/>
# </td>
# <td class="TableContent" nowrap="nowrap" valign="top" width="55%">
# <b>Roll No: </b>
# 																	10029
# 																	<br/>
# <br/>
# <p>
# <b>Name: </b>
# 																		ABHISHEK PRASAD SAHOO
# 																	</p>
# <p>
# <b>Program: </b>
# 																		BTech
# 																	</p>
# <p>
# <b>Department: </b>
# 																		MATERIALS SCIENCE &amp; ENGG.
# 																	</p>
# <p>
# <b>Hostel Info: </b>
# 																		NRA, 123
# 																		<br/>
# </p>
# <p>
# <b> E-Mail: </b><a href="mailto:apsahoo@iitk.ac.in">apsahoo@iitk.ac.in
# 																		</a>
# </p>
# <p>
# <b> Blood Group:</b>
# 																		O+
# 																		<!--<b> Category:</b>GN<br></P>-->
# </p>
# <p>
# <b> Gender:</b>
# 																		M
# 																		<b> CountryOfOrigin:</b>
# 																		India
# 																		<br/>
# </p>
# <!--<p><b>Local Address :</b>Not Available<br>Not Available<br>
# 		Phone no:Not Available<br>Mobile no:Not Available</P>
# 		<p><b>Permanent Address :</b>RABI NARAYAN SAHOO<br>QTR-216/6, NAVAL BASE,INS CHILKA,KHURDA,Orissa,India<br>
#   		Phone no:9861018014<br>Mobile no:Not Available</P>
#                 <p><a href="Stff_Addr.jsp?typ=stud&pfno=10029">Address</a></p>-->
# </td>
# </tr>
# </table>
# <font></font>
# </center>
# </div>
# </td>
# <td></td>
# </tr>
# </table>
# <br/>
# </td>
# </tr>
# </table>
#
#
#
# <center>
# <br/>
# <br/>
# <br/>
# <table border="0" cellpadding="2" cellspacing="0">
# <tr>
# <td colspan="10">
# <input class="submit_button" name="sbmbtn1" onclick="backfn();" type="button" value="Back"/>
# </td>
# </tr>
# </table>
# </center>
# </form>
# </body>
# </html>
#
# <a href="javascript:searchres('10032');">10032
# 						</a>
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Oracle JDeveloper" name="GENERATOR"/>
# <meta content="no-cache" http-equiv="cache-control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <link href="oasback.css" rel="Stylesheet" type="text/css"/>
# <title>Search_name</title>
# </head>
# <script language="javascript" type="text/javascript">
#
#  var message="";
# 			function clickIE()
# 			{
# 				if (document.all) {alert(message);return false;}
# 			}
# 			function clickNS(e)
# 			{
# 				if (document.layers||(document.getElementById&&!document.all))
# 				{
# 				  	if (e.which==2||e.which==3)
# 				  		{
# 				  			// alert(message);
# 				  			return false;
# 				  		}
# 				}
# 			}
# 				  	if (document.layers)
# 				  	{document.captureEvents(Event.MOUSEDOWN);document.onmousedown=clickNS;}
# 				  	else{document.onmouseup=clickNS;document.oncontextmenu=clickIE;}
# 			  	document.oncontextmenu=new Function("return false")
#
#
#   var s1;
#
#
#   function IsEmptyString(str)
# {
# 	nLen = str.length;
# 	for(i=0; i<nLen; ++i)
# 	{
# 		if(str.charAt(i) != " ")
# 		{
# 			return false;
# 		}
# 	}
# 	return true;
# }
#
#
# function next()
# {
#
# document.Srchfrm1.submit();
#
# }
#
# function prev(val)
# {
#
# document.Srchfrm1.recpos.value=val;
# document.Srchfrm1.submit();
# }
#
# function searchres(x){
#
#  document.Srchfrm1.numtxt.value=x;
# document.Srchfrm1.action="IITk_SrchRes_new.jsp";
# document.Srchfrm1.method="POST";
# document.Srchfrm1.submit();
#
# }
#
# </script>
# <body leftmargin="0" marginheight="0" marginwidth="0" topmargin="0">
# <p>
#
# 		</p>
# <form action="IITk_SrchStudRoll_new.jsp" method="post" name="Srchfrm1">
# <input name="k1" type="hidden" value="#ADELukNhHiN=H!_@/JyAGZyZaIWB$juKblR&amp;KFEtBFWNSo%p-#OTCX"/>
# <input name="k2" type="hidden" value="Jp=IE&amp;CFHUp_UOIXYaPQhmTCH_U/xz&amp;u@fZoiPraG-YuUEsoEBGVr$S"/>
# <input name="k3" type="hidden" value="gnYJd#NsOd-WphfNDrZ_FVDEAFGew!nRBih$@WDLSEhTXVJeHjLBSuI"/>
# <input name="numtxt" type="hidden" value="">
# <table align="center" border="0" width="100%">
# <tr>
# <td align="center" class="tablehead">
# 						Student Search
# 					</td>
# </tr>
# </table>
# <br/>
# <div align="left" class="DivContent">
#
# 				You are viewing
# 				<b>1 </b> to
# 				<b>12 </b> records out of
# 				<b>12669 </b> records
#
#
# 			</div>
# <br/>
# <table border="0" cellpadding="1" cellspacing="1" width="100%">
# <tr bgcolor="darkblue">
# <th align="left" class="TableHead">
# 						Rollno
# 					</th>
# <th align="left" class="TableHead">
# 						Name
# 					</th>
# <th align="left" class="TableHead">
# 						Department
# 					</th>
# <th align="left" class="TableHead">
# 						Program
# 					</th>
# <th align="left" class="TableHead">
# 						Blood Group
# 					</th>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud">
# <input name="sbm" type="hidden" value="Y">
# <a href="javascript:searchres('10017');">10017
# 						</a>
# </input></input></td>
# <td class="TableText">
# 						ABHISHEK ANAND YADAV
# 					</td>
# <td class="TableText">
# 						PHYSICS
# 					</td>
# <td class="TableText">
# 						MSc(Int)
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10029');">10029
# 						</a>
# </td>
# <td class="TableText">
# 						ABHISHEK PRASAD SAHOO
# 					</td>
# <td class="TableText">
# 						MATERIALS SCIENCE &amp; ENGG.
# 					</td>
# <td class="TableText">
# 						BTech
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10032');">10032
# 						</a>
# </td>
# <td class="TableText">
# 						ABHISHEK S SAYAM
# 					</td>
# <td class="TableText">
# 						COMPUTER SCIENCE &amp; ENGG.
# 					</td>
# <td class="TableText">
# 						MT(Dual)
# 					</td>
# <td class="TableText">
# 						B+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10047');">10047
# 						</a>
# </td>
# <td class="TableText">
# 						AJIT KUMAR
# 					</td>
# <td class="TableText">
# 						CIVIL ENGG.
# 					</td>
# <td class="TableText">
# 						BTech
# 					</td>
# <td class="TableText">
# 						B+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10053');">10053
# 						</a>
# </td>
# <td class="TableText">
# 						AKASH  KUMAR
# 					</td>
# <td class="TableText">
# 						CIVIL ENGG.
# 					</td>
# <td class="TableText">
# 						MT(Dual)
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10088');">10088
# 						</a>
# </td>
# <td class="TableText">
# 						ANIL  KUMAR
# 					</td>
# <td class="TableText">
# 						ELECTRICAL ENGG.
# 					</td>
# <td class="TableText">
# 						BTech
# 					</td>
# <td class="TableText">
# 						AB+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10100063');">10100063
# 						</a>
# </td>
# <td class="TableText">
# 						TARUSHIKHA  SARVESH
# 					</td>
# <td class="TableText">
# 						HUMANITIES &amp; SOC. SCIENCES
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						B+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10101061');">10101061
# 						</a>
# </td>
# <td class="TableText">
# 						ANSHUL  KHANDELWAL
# 					</td>
# <td class="TableText">
# 						AEROSPACE ENGG.
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10101065');">10101065
# 						</a>
# </td>
# <td class="TableText">
# 						SUNIL  KUMAR
# 					</td>
# <td class="TableText">
# 						AEROSPACE ENGG.
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10101066');">10101066
# 						</a>
# </td>
# <td class="TableText">
# 						DAVINDER SINGH BHOGAL
# 					</td>
# <td class="TableText">
# 						AEROSPACE ENGG.
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10102043');">10102043
# 						</a>
# </td>
# <td class="TableText">
# 						VINOD DIGAMBAR DAHAKE
# 					</td>
# <td class="TableText">
# 						CHEMICAL ENGG.
# 					</td>
# <td class="TableText">
# 						MTech
# 					</td>
# <td class="TableText">
# 						AB+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10103003');">10103003
# 						</a>
# </td>
# <td class="TableText">
# 						ARTI  KUMARI
# 					</td>
# <td class="TableText">
# 						CIVIL ENGG.
# 					</td>
# <td class="TableText">
# 						MTech
# 					</td>
# <td class="TableText">
# 						A+
# 					</td>
# </tr>
# </table>
# <table align="right">
# <tr>
# <td>
# <input id="recpos" name="recpos" type="hidden" value="12"/>
# <input name="selstudrol" type="hidden" value=""/>
# <input name="selstuddep" type="hidden" value=""/>
# <input name="selstudnam" type="hidden" value=""/>
# <!--<font color="Darkmagenta" size=2  style="cursor:hand;" title="Next"><b>-->
# <a href="javascript:next()">NEXT</a><b></b>
# </td>
# </tr>
# </table>
# </input></form>
# </body>
# </html>
#
# -----------------------
# 10032
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Oracle JDeveloper" name="GENERATOR"/>
# <title>Search -IITK</title>
# <link href="oasback.css" rel="Stylesheet" type="text/css"/>
# <script language="JavaScript" type="text/javascript">
#  var message="";
# 			function clickIE()
# 			{
# 				if (document.all) {alert(message);return false;}
# 			}
# 			function clickNS(e)
# 			{
# 				if (document.layers||(document.getElementById&&!document.all))
# 				{
# 				  	if (e.which==2||e.which==3)
# 				  		{
# 				  			// alert(message);
# 				  			return false;
# 				  		}
# 				}
# 			}
# 				  	if (document.layers)
# 				  	{document.captureEvents(Event.MOUSEDOWN);document.onmousedown=clickNS;}
# 				  	else{document.onmouseup=clickNS;document.oncontextmenu=clickIE;}
# 			  	document.oncontextmenu=new Function("return false")
#
#
# function frmsbm()
# {
# 	var x;
# 	x = 0;
# 	if(IsEmptyString(document.srchfrm.numtxt.value))
# 	{
# 		alert("Please enter Pfno/RollNo to search");
# 		document.srchfrm.numtxt.focus();
# 		x=x+1;
# 		return false;
# 	}
#   if(x==0)
#   {
#     document.srchfrm.method = "post";
# 		document.srchfrm.action= "IITk_SrchRes_new.jsp?sbm=Y";
# 		document.srchfrm.submit();
# 	}
# 	return true;
# }
#
#
# function IsEmptyString(str)
# {
# 	nLen = str.length;
# 	for(i=0; i<nLen; ++i)
# 	{
# 		if(str.charAt(i) != " ")
# 		{
# 			return false;
# 		}
# 	}
# 	return true;
# }
#
# function backfn()
# {
# if (document.srchfrm.bk.value=="Y")
# {
#  document.srchfrm.method="post";
#  document.srchfrm.action="IITK_Srch.jsp?typ=stud";
#  document.srchfrm.submit();
# }
# else
# window.history.go(-1);
# }
#
# </script>
# </head>
# <body bgcolor="lightsteelblue" leftmargin="20" marginheight="0" marginwidth="0" onload="document.srchfrm.numtxt.focus();" text="#000000" topmargin="0">
# <br/>
# <form action="" method="get" name="srchfrm" onsubmit="frmsbm();">
# <input name="typ" type="hidden" value="stud"/>
# <input name="bk" type="hidden" value=""/>
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="center" valign="top">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td align="left" valign="top">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td>
# <img alt="" height="10" src="images/transparent.gif" width="1"/>
# </td>
# </tr>
# <tr></tr>
# <tr>
# <td>
# <table border="0" cellpadding="2" cellspacing="0">
# <tr class="TableContent">
# </tr></table></td>
# <td height="20">
# <b>Enter Student RollNo:</b>
# </td>
# <td class="menu1" height="20" nowrap="nowrap">
# <input name="numtxt" size="15" type="text"/>
#
# 															<input class="submit_button" name="sbmbtn" onclick="frmsbm();" title="NEW" type="button" value="Submit"/>
# </td>
# </tr>
# <tr>
# <td height="20"></td>
# </tr>
# </table>
# <br/>
# <div align="center">
# <center>
# <table border="0" cellpadding="2" cellspacing="2" width="100%">
# <tr>
# <td align="right" valign="top" width="25%">
# <img alt="" height="130" src="https://oa.cc.iitk.ac.in:443/Oa/Jsp/Photo/10032_0.jpg" width="130"/>
# </td>
# <td class="TableContent" nowrap="nowrap" valign="top" width="55%">
# <b>Roll No: </b>
# 																	10032
# 																	<br/>
# <br/>
# <p>
# <b>Name: </b>
# 																		ABHISHEK S SAYAM
# 																	</p>
# <p>
# <b>Program: </b>
# 																		MT(Dual)
# 																	</p>
# <p>
# <b>Department: </b>
# 																		COMPUTER SCIENCE &amp; ENGG.
# 																	</p>
# <p>
# <b>Hostel Info: </b>
# 																		HALL3, 104
# 																		<br/>
# </p>
# <p>
# <b> E-Mail: </b><a href="mailto:sayam@iitk.ac.in">sayam@iitk.ac.in
# 																		</a>
# </p>
# <p>
# <b> Blood Group:</b>
# 																		B+
# 																		<!--<b> Category:</b>ST<br></P>-->
# </p>
# <p>
# <b> Gender:</b>
# 																		M
# 																		<b> CountryOfOrigin:</b>
# 																		India
# 																		<br/>
# </p>
# <!--<p><b>Local Address :</b>Not Available<br>Not Available<br>
# 		Phone no:Not Available<br>Mobile no:Not Available</P>
# 		<p><b>Permanent Address :</b>S K Sayam<br>18, Manish Nagar,Somalwada,Nagpur,Maharashtra,India<br>
#   		Phone no:09823561251<br>Mobile no:09823793601</P>
#                 <p><a href="Stff_Addr.jsp?typ=stud&pfno=10032">Address</a></p>-->
# </td>
# </tr>
# </table>
# <font></font>
# </center>
# </div>
# </td>
# <td></td>
# </tr>
# </table>
# <br/>
# </td>
# </tr>
# </table>
#
#
#
# <center>
# <br/>
# <br/>
# <br/>
# <table border="0" cellpadding="2" cellspacing="0">
# <tr>
# <td colspan="10">
# <input class="submit_button" name="sbmbtn1" onclick="backfn();" type="button" value="Back"/>
# </td>
# </tr>
# </table>
# </center>
# </form>
# </body>
# </html>
#
# <a href="javascript:searchres('10047');">10047
# 						</a>
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Oracle JDeveloper" name="GENERATOR"/>
# <meta content="no-cache" http-equiv="cache-control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <link href="oasback.css" rel="Stylesheet" type="text/css"/>
# <title>Search_name</title>
# </head>
# <script language="javascript" type="text/javascript">
#
#  var message="";
# 			function clickIE()
# 			{
# 				if (document.all) {alert(message);return false;}
# 			}
# 			function clickNS(e)
# 			{
# 				if (document.layers||(document.getElementById&&!document.all))
# 				{
# 				  	if (e.which==2||e.which==3)
# 				  		{
# 				  			// alert(message);
# 				  			return false;
# 				  		}
# 				}
# 			}
# 				  	if (document.layers)
# 				  	{document.captureEvents(Event.MOUSEDOWN);document.onmousedown=clickNS;}
# 				  	else{document.onmouseup=clickNS;document.oncontextmenu=clickIE;}
# 			  	document.oncontextmenu=new Function("return false")
#
#
#   var s1;
#
#
#   function IsEmptyString(str)
# {
# 	nLen = str.length;
# 	for(i=0; i<nLen; ++i)
# 	{
# 		if(str.charAt(i) != " ")
# 		{
# 			return false;
# 		}
# 	}
# 	return true;
# }
#
#
# function next()
# {
#
# document.Srchfrm1.submit();
#
# }
#
# function prev(val)
# {
#
# document.Srchfrm1.recpos.value=val;
# document.Srchfrm1.submit();
# }
#
# function searchres(x){
#
#  document.Srchfrm1.numtxt.value=x;
# document.Srchfrm1.action="IITk_SrchRes_new.jsp";
# document.Srchfrm1.method="POST";
# document.Srchfrm1.submit();
#
# }
#
# </script>
# <body leftmargin="0" marginheight="0" marginwidth="0" topmargin="0">
# <p>
#
# 		</p>
# <form action="IITk_SrchStudRoll_new.jsp" method="post" name="Srchfrm1">
# <input name="k1" type="hidden" value="#ADELukNhHiN=H!_@/JyAGZyZaIWB$juKblR&amp;KFEtBFWNSo%p-#OTCX"/>
# <input name="k2" type="hidden" value="Jp=IE&amp;CFHUp_UOIXYaPQhmTCH_U/xz&amp;u@fZoiPraG-YuUEsoEBGVr$S"/>
# <input name="k3" type="hidden" value="gnYJd#NsOd-WphfNDrZ_FVDEAFGew!nRBih$@WDLSEhTXVJeHjLBSuI"/>
# <input name="numtxt" type="hidden" value="">
# <table align="center" border="0" width="100%">
# <tr>
# <td align="center" class="tablehead">
# 						Student Search
# 					</td>
# </tr>
# </table>
# <br/>
# <div align="left" class="DivContent">
#
# 				You are viewing
# 				<b>1 </b> to
# 				<b>12 </b> records out of
# 				<b>12669 </b> records
#
#
# 			</div>
# <br/>
# <table border="0" cellpadding="1" cellspacing="1" width="100%">
# <tr bgcolor="darkblue">
# <th align="left" class="TableHead">
# 						Rollno
# 					</th>
# <th align="left" class="TableHead">
# 						Name
# 					</th>
# <th align="left" class="TableHead">
# 						Department
# 					</th>
# <th align="left" class="TableHead">
# 						Program
# 					</th>
# <th align="left" class="TableHead">
# 						Blood Group
# 					</th>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud">
# <input name="sbm" type="hidden" value="Y">
# <a href="javascript:searchres('10017');">10017
# 						</a>
# </input></input></td>
# <td class="TableText">
# 						ABHISHEK ANAND YADAV
# 					</td>
# <td class="TableText">
# 						PHYSICS
# 					</td>
# <td class="TableText">
# 						MSc(Int)
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10029');">10029
# 						</a>
# </td>
# <td class="TableText">
# 						ABHISHEK PRASAD SAHOO
# 					</td>
# <td class="TableText">
# 						MATERIALS SCIENCE &amp; ENGG.
# 					</td>
# <td class="TableText">
# 						BTech
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10032');">10032
# 						</a>
# </td>
# <td class="TableText">
# 						ABHISHEK S SAYAM
# 					</td>
# <td class="TableText">
# 						COMPUTER SCIENCE &amp; ENGG.
# 					</td>
# <td class="TableText">
# 						MT(Dual)
# 					</td>
# <td class="TableText">
# 						B+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10047');">10047
# 						</a>
# </td>
# <td class="TableText">
# 						AJIT KUMAR
# 					</td>
# <td class="TableText">
# 						CIVIL ENGG.
# 					</td>
# <td class="TableText">
# 						BTech
# 					</td>
# <td class="TableText">
# 						B+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10053');">10053
# 						</a>
# </td>
# <td class="TableText">
# 						AKASH  KUMAR
# 					</td>
# <td class="TableText">
# 						CIVIL ENGG.
# 					</td>
# <td class="TableText">
# 						MT(Dual)
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10088');">10088
# 						</a>
# </td>
# <td class="TableText">
# 						ANIL  KUMAR
# 					</td>
# <td class="TableText">
# 						ELECTRICAL ENGG.
# 					</td>
# <td class="TableText">
# 						BTech
# 					</td>
# <td class="TableText">
# 						AB+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10100063');">10100063
# 						</a>
# </td>
# <td class="TableText">
# 						TARUSHIKHA  SARVESH
# 					</td>
# <td class="TableText">
# 						HUMANITIES &amp; SOC. SCIENCES
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						B+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10101061');">10101061
# 						</a>
# </td>
# <td class="TableText">
# 						ANSHUL  KHANDELWAL
# 					</td>
# <td class="TableText">
# 						AEROSPACE ENGG.
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10101065');">10101065
# 						</a>
# </td>
# <td class="TableText">
# 						SUNIL  KUMAR
# 					</td>
# <td class="TableText">
# 						AEROSPACE ENGG.
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10101066');">10101066
# 						</a>
# </td>
# <td class="TableText">
# 						DAVINDER SINGH BHOGAL
# 					</td>
# <td class="TableText">
# 						AEROSPACE ENGG.
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10102043');">10102043
# 						</a>
# </td>
# <td class="TableText">
# 						VINOD DIGAMBAR DAHAKE
# 					</td>
# <td class="TableText">
# 						CHEMICAL ENGG.
# 					</td>
# <td class="TableText">
# 						MTech
# 					</td>
# <td class="TableText">
# 						AB+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10103003');">10103003
# 						</a>
# </td>
# <td class="TableText">
# 						ARTI  KUMARI
# 					</td>
# <td class="TableText">
# 						CIVIL ENGG.
# 					</td>
# <td class="TableText">
# 						MTech
# 					</td>
# <td class="TableText">
# 						A+
# 					</td>
# </tr>
# </table>
# <table align="right">
# <tr>
# <td>
# <input id="recpos" name="recpos" type="hidden" value="12"/>
# <input name="selstudrol" type="hidden" value=""/>
# <input name="selstuddep" type="hidden" value=""/>
# <input name="selstudnam" type="hidden" value=""/>
# <!--<font color="Darkmagenta" size=2  style="cursor:hand;" title="Next"><b>-->
# <a href="javascript:next()">NEXT</a><b></b>
# </td>
# </tr>
# </table>
# </input></form>
# </body>
# </html>
#
# -----------------------
# 10047
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Oracle JDeveloper" name="GENERATOR"/>
# <title>Search -IITK</title>
# <link href="oasback.css" rel="Stylesheet" type="text/css"/>
# <script language="JavaScript" type="text/javascript">
#  var message="";
# 			function clickIE()
# 			{
# 				if (document.all) {alert(message);return false;}
# 			}
# 			function clickNS(e)
# 			{
# 				if (document.layers||(document.getElementById&&!document.all))
# 				{
# 				  	if (e.which==2||e.which==3)
# 				  		{
# 				  			// alert(message);
# 				  			return false;
# 				  		}
# 				}
# 			}
# 				  	if (document.layers)
# 				  	{document.captureEvents(Event.MOUSEDOWN);document.onmousedown=clickNS;}
# 				  	else{document.onmouseup=clickNS;document.oncontextmenu=clickIE;}
# 			  	document.oncontextmenu=new Function("return false")
#
#
# function frmsbm()
# {
# 	var x;
# 	x = 0;
# 	if(IsEmptyString(document.srchfrm.numtxt.value))
# 	{
# 		alert("Please enter Pfno/RollNo to search");
# 		document.srchfrm.numtxt.focus();
# 		x=x+1;
# 		return false;
# 	}
#   if(x==0)
#   {
#     document.srchfrm.method = "post";
# 		document.srchfrm.action= "IITk_SrchRes_new.jsp?sbm=Y";
# 		document.srchfrm.submit();
# 	}
# 	return true;
# }
#
#
# function IsEmptyString(str)
# {
# 	nLen = str.length;
# 	for(i=0; i<nLen; ++i)
# 	{
# 		if(str.charAt(i) != " ")
# 		{
# 			return false;
# 		}
# 	}
# 	return true;
# }
#
# function backfn()
# {
# if (document.srchfrm.bk.value=="Y")
# {
#  document.srchfrm.method="post";
#  document.srchfrm.action="IITK_Srch.jsp?typ=stud";
#  document.srchfrm.submit();
# }
# else
# window.history.go(-1);
# }
#
# </script>
# </head>
# <body bgcolor="lightsteelblue" leftmargin="20" marginheight="0" marginwidth="0" onload="document.srchfrm.numtxt.focus();" text="#000000" topmargin="0">
# <br/>
# <form action="" method="get" name="srchfrm" onsubmit="frmsbm();">
# <input name="typ" type="hidden" value="stud"/>
# <input name="bk" type="hidden" value=""/>
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="center" valign="top">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td align="left" valign="top">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td>
# <img alt="" height="10" src="images/transparent.gif" width="1"/>
# </td>
# </tr>
# <tr></tr>
# <tr>
# <td>
# <table border="0" cellpadding="2" cellspacing="0">
# <tr class="TableContent">
# </tr></table></td>
# <td height="20">
# <b>Enter Student RollNo:</b>
# </td>
# <td class="menu1" height="20" nowrap="nowrap">
# <input name="numtxt" size="15" type="text"/>
#
# ...
# 		document.srchfrm.numtxt.focus();
# 		x=x+1;
# 		return false;
# 	}
#   if(x==0)
#   {
#     document.srchfrm.method = "post";
# 		document.srchfrm.action= "IITk_SrchRes_new.jsp?sbm=Y";
# 		document.srchfrm.submit();
# 	}
# 	return true;
# }
#
#
# function IsEmptyString(str)
# {
# 	nLen = str.length;
# 	for(i=0; i<nLen; ++i)
# 	{
# 		if(str.charAt(i) != " ")
# 		{
# 			return false;
# 		}
# 	}
# 	return true;
# }
#
# function backfn()
# {
# if (document.srchfrm.bk.value=="Y")
# {
#  document.srchfrm.method="post";
#  document.srchfrm.action="IITK_Srch.jsp?typ=stud";
#  document.srchfrm.submit();
# }
# else
# window.history.go(-1);
# }
#
# </script>
# </head>
# <body bgcolor="lightsteelblue" leftmargin="20" marginheight="0" marginwidth="0" onload="document.srchfrm.numtxt.focus();" text="#000000" topmargin="0">
# <br/>
# <form action="" method="get" name="srchfrm" onsubmit="frmsbm();">
# <input name="typ" type="hidden" value="stud"/>
# <input name="bk" type="hidden" value=""/>
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="center" valign="top">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td align="left" valign="top">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td>
# <img alt="" height="10" src="images/transparent.gif" width="1"/>
# </td>
# </tr>
# <tr></tr>
# <tr>
# <td>
# <table border="0" cellpadding="2" cellspacing="0">
# <tr class="TableContent">
# </tr></table></td>
# <td height="20">
# <b>Enter Student RollNo:</b>
# </td>
# <td class="menu1" height="20" nowrap="nowrap">
# <input name="numtxt" size="15" type="text"/>
#
# 															<input class="submit_button" name="sbmbtn" onclick="frmsbm();" title="NEW" type="button" value="Submit"/>
# </td>
# </tr>
# <tr>
# <td height="20"></td>
# </tr>
# </table>
# <br/>
# <div align="center">
# <center>
# <table border="0" cellpadding="2" cellspacing="2" width="100%">
# <tr>
# <td align="right" valign="top" width="25%">
# <img alt="" height="130" src="https://oa.cc.iitk.ac.in:443/Oa/Jsp/Photo/10102043_0.jpg" width="130"/>
# </td>
# <td class="TableContent" nowrap="nowrap" valign="top" width="55%">
# <b>Roll No: </b>
# 																	10102043
# 																	<br/>
# <br/>
# <p>
# <b>Name: </b>
# 																		VINOD DIGAMBAR DAHAKE
# 																	</p>
# <p>
# <b>Program: </b>
# 																		MTech
# 																	</p>
# <p>
# <b>Department: </b>
# 																		CHEMICAL ENGG.
# 																	</p>
# <p>
# <b>Hostel Info: </b>
# 																		HALL8, A-214
# 																		<br/>
# </p>
# <p>
# <b> E-Mail: </b><a href="mailto:dahanod@iitk.ac.in">dahanod@iitk.ac.in
# 																		</a>
# </p>
# <p>
# <b> Blood Group:</b>
# 																		AB+
# 																		<!--<b> Category:</b>OB<br></P>-->
# </p>
# <p>
# <b> Gender:</b>
# 																		M
# 																		<b> CountryOfOrigin:</b>
# 																		India
# 																		<br/>
# </p>
# <!--<p><b>Local Address :</b>Not Available<br>Not Available<br>
# 		Phone no:Not Available<br>Mobile no:Not Available</P>
# 		<p><b>Permanent Address :</b>Digambar Maroti Dahake<br>AT-Wakeshwar POST-Jaoli TA-Bhiwapur ,Dist-Nagpur,Nagpur,Maharashtra,India<br>
#   		Phone no:9420444634<br>Mobile no:09766223876</P>
#                 <p><a href="Stff_Addr.jsp?typ=stud&pfno=10102043">Address</a></p>-->
# </td>
# </tr>
# </table>
# <font></font>
# </center>
# </div>
# </td>
# <td></td>
# </tr>
# </table>
# <br/>
# </td>
# </tr>
# </table>
#
#
#
# <center>
# <br/>
# <br/>
# <br/>
# <table border="0" cellpadding="2" cellspacing="0">
# <tr>
# <td colspan="10">
# <input class="submit_button" name="sbmbtn1" onclick="backfn();" type="button" value="Back"/>
# </td>
# </tr>
# </table>
# </center>
# </form>
# </body>
# </html>
#
# <a href="javascript:searchres('10103003');">10103003
# 						</a>
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Oracle JDeveloper" name="GENERATOR"/>
# <meta content="no-cache" http-equiv="cache-control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <link href="oasback.css" rel="Stylesheet" type="text/css"/>
# <title>Search_name</title>
# </head>
# <script language="javascript" type="text/javascript">
#
#  var message="";
# 			function clickIE()
# 			{
# 				if (document.all) {alert(message);return false;}
# 			}
# 			function clickNS(e)
# 			{
# 				if (document.layers||(document.getElementById&&!document.all))
# 				{
# 				  	if (e.which==2||e.which==3)
# 				  		{
# 				  			// alert(message);
# 				  			return false;
# 				  		}
# 				}
# 			}
# 				  	if (document.layers)
# 				  	{document.captureEvents(Event.MOUSEDOWN);document.onmousedown=clickNS;}
# 				  	else{document.onmouseup=clickNS;document.oncontextmenu=clickIE;}
# 			  	document.oncontextmenu=new Function("return false")
#
#
#   var s1;
#
#
#   function IsEmptyString(str)
# {
# 	nLen = str.length;
# 	for(i=0; i<nLen; ++i)
# 	{
# 		if(str.charAt(i) != " ")
# 		{
# 			return false;
# 		}
# 	}
# 	return true;
# }
#
#
# function next()
# {
#
# document.Srchfrm1.submit();
#
# }
#
# function prev(val)
# {
#
# document.Srchfrm1.recpos.value=val;
# document.Srchfrm1.submit();
# }
#
# function searchres(x){
#
#  document.Srchfrm1.numtxt.value=x;
# document.Srchfrm1.action="IITk_SrchRes_new.jsp";
# document.Srchfrm1.method="POST";
# document.Srchfrm1.submit();
#
# }
#
# </script>
# <body leftmargin="0" marginheight="0" marginwidth="0" topmargin="0">
# <p>
#
# 		</p>
# <form action="IITk_SrchStudRoll_new.jsp" method="post" name="Srchfrm1">
# <input name="k1" type="hidden" value="#ADELukNhHiN=H!_@/JyAGZyZaIWB$juKblR&amp;KFEtBFWNSo%p-#OTCX"/>
# <input name="k2" type="hidden" value="Jp=IE&amp;CFHUp_UOIXYaPQhmTCH_U/xz&amp;u@fZoiPraG-YuUEsoEBGVr$S"/>
# <input name="k3" type="hidden" value="gnYJd#NsOd-WphfNDrZ_FVDEAFGew!nRBih$@WDLSEhTXVJeHjLBSuI"/>
# <input name="numtxt" type="hidden" value="">
# <table align="center" border="0" width="100%">
# <tr>
# <td align="center" class="tablehead">
# 						Student Search
# 					</td>
# </tr>
# </table>
# <br/>
# <div align="left" class="DivContent">
#
# 				You are viewing
# 				<b>1 </b> to
# 				<b>12 </b> records out of
# 				<b>12669 </b> records
#
#
# 			</div>
# <br/>
# <table border="0" cellpadding="1" cellspacing="1" width="100%">
# <tr bgcolor="darkblue">
# <th align="left" class="TableHead">
# 						Rollno
# 					</th>
# <th align="left" class="TableHead">
# 						Name
# 					</th>
# <th align="left" class="TableHead">
# 						Department
# 					</th>
# <th align="left" class="TableHead">
# 						Program
# 					</th>
# <th align="left" class="TableHead">
# 						Blood Group
# 					</th>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud">
# <input name="sbm" type="hidden" value="Y">
# <a href="javascript:searchres('10017');">10017
# 						</a>
# </input></input></td>
# <td class="TableText">
# 						ABHISHEK ANAND YADAV
# 					</td>
# <td class="TableText">
# 						PHYSICS
# 					</td>
# <td class="TableText">
# 						MSc(Int)
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10029');">10029
# 						</a>
# </td>
# <td class="TableText">
# 						ABHISHEK PRASAD SAHOO
# 					</td>
# <td class="TableText">
# 						MATERIALS SCIENCE &amp; ENGG.
# 					</td>
# <td class="TableText">
# 						BTech
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10032');">10032
# 						</a>
# </td>
# <td class="TableText">
# 						ABHISHEK S SAYAM
# 					</td>
# <td class="TableText">
# 						COMPUTER SCIENCE &amp; ENGG.
# 					</td>
# <td class="TableText">
# 						MT(Dual)
# 					</td>
# <td class="TableText">
# 						B+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10047');">10047
# 						</a>
# </td>
# <td class="TableText">
# 						AJIT KUMAR
# 					</td>
# <td class="TableText">
# 						CIVIL ENGG.
# 					</td>
# <td class="TableText">
# 						BTech
# 					</td>
# <td class="TableText">
# 						B+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10053');">10053
# 						</a>
# </td>
# <td class="TableText">
# 						AKASH  KUMAR
# 					</td>
# <td class="TableText">
# 						CIVIL ENGG.
# 					</td>
# <td class="TableText">
# 						MT(Dual)
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10088');">10088
# 						</a>
# </td>
# <td class="TableText">
# 						ANIL  KUMAR
# 					</td>
# <td class="TableText">
# 						ELECTRICAL ENGG.
# 					</td>
# <td class="TableText">
# 						BTech
# 					</td>
# <td class="TableText">
# 						AB+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10100063');">10100063
# 						</a>
# </td>
# <td class="TableText">
# 						TARUSHIKHA  SARVESH
# 					</td>
# <td class="TableText">
# 						HUMANITIES &amp; SOC. SCIENCES
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						B+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10101061');">10101061
# 						</a>
# </td>
# <td class="TableText">
# 						ANSHUL  KHANDELWAL
# 					</td>
# <td class="TableText">
# 						AEROSPACE ENGG.
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10101065');">10101065
# 						</a>
# </td>
# <td class="TableText">
# 						SUNIL  KUMAR
# 					</td>
# <td class="TableText">
# 						AEROSPACE ENGG.
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10101066');">10101066
# 						</a>
# </td>
# <td class="TableText">
# 						DAVINDER SINGH BHOGAL
# 					</td>
# <td class="TableText">
# 						AEROSPACE ENGG.
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10102043');">10102043
# 						</a>
# </td>
# <td class="TableText">
# 						VINOD DIGAMBAR DAHAKE
# 					</td>
# <td class="TableText">
# 						CHEMICAL ENGG.
# 					</td>
# <td class="TableText">
# 						MTech
# 					</td>
# <td class="TableText">
# 						AB+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10103003');">10103003
# 						</a>
# </td>
# <td class="TableText">
# 						ARTI  KUMARI
# 					</td>
# <td class="TableText">
# 						CIVIL ENGG.
# 					</td>
# <td class="TableText">
# 						MTech
# 					</td>
# <td class="TableText">
# 						A+
# 					</td>
# </tr>
# </table>
# <table align="right">
# <tr>
# <td>
# <input id="recpos" name="recpos" type="hidden" value="12"/>
# <input name="selstudrol" type="hidden" value=""/>
# <input name="selstuddep" type="hidden" value=""/>
# <input name="selstudnam" type="hidden" value=""/>
# <!--<font color="Darkmagenta" size=2  style="cursor:hand;" title="Next"><b>-->
# <a href="javascript:next()">NEXT</a><b></b>
# </td>
# </tr>
# </table>
# </input></form>
# </body>
# </html>
#
# -----------------------
# 10103003
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Oracle JDeveloper" name="GENERATOR"/>
# <title>Search -IITK</title>
# <link href="oasback.css" rel="Stylesheet" type="text/css"/>
# <script language="JavaScript" type="text/javascript">
#  var message="";
# 			function clickIE()
# 			{
# 				if (document.all) {alert(message);return false;}
# 			}
# 			function clickNS(e)
# 			{
# 				if (document.layers||(document.getElementById&&!document.all))
# 				{
# 				  	if (e.which==2||e.which==3)
# 				  		{
# 				  			// alert(message);
# 				  			return false;
# 				  		}
# 				}
# 			}
# 				  	if (document.layers)
# 				  	{document.captureEvents(Event.MOUSEDOWN);document.onmousedown=clickNS;}
# 				  	else{document.onmouseup=clickNS;document.oncontextmenu=clickIE;}
# 			  	document.oncontextmenu=new Function("return false")
#
#
# function frmsbm()
# {
# 	var x;
# 	x = 0;
# 	if(IsEmptyString(document.srchfrm.numtxt.value))
# 	{
# 		alert("Please enter Pfno/RollNo to search");
# 		document.srchfrm.numtxt.focus();
# 		x=x+1;
# 		return false;
# 	}
#   if(x==0)
#   {
#     document.srchfrm.method = "post";
# 		document.srchfrm.action= "IITk_SrchRes_new.jsp?sbm=Y";
# 		document.srchfrm.submit();
# 	}
# 	return true;
# }
#
#
# function IsEmptyString(str)
# {
# 	nLen = str.length;
# 	for(i=0; i<nLen; ++i)
# 	{
# 		if(str.charAt(i) != " ")
# 		{
# 			return false;
# 		}
# 	}
# 	return true;
# }
#
# function backfn()
# {
# if (document.srchfrm.bk.value=="Y")
# {
#  document.srchfrm.method="post";
#  document.srchfrm.action="IITK_Srch.jsp?typ=stud";
#  document.srchfrm.submit();
# }
# else
# window.history.go(-1);
# }
#
# </script>
# </head>
# <body bgcolor="lightsteelblue" leftmargin="20" marginheight="0" marginwidth="0" onload="document.srchfrm.numtxt.focus();" text="#000000" topmargin="0">
# <br/>
# <form action="" method="get" name="srchfrm" onsubmit="frmsbm();">
# <input name="typ" type="hidden" value="stud"/>
# <input name="bk" type="hidden" value=""/>
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="center" valign="top">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td align="left" valign="top">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td>
# <img alt="" height="10" src="images/transparent.gif" width="1"/>
# </td>
# </tr>
# <tr></tr>
# <tr>
# <td>
# <table border="0" cellpadding="2" cellspacing="0">
# <tr class="TableContent">
# </tr></table></td>
# <td height="20">
# <b>Enter Student RollNo:</b>
# </td>
# <td class="menu1" height="20" nowrap="nowrap">
# <input name="numtxt" size="15" type="text"/>
#
# 															<input class="submit_button" name="sbmbtn" onclick="frmsbm();" title="NEW" type="button" value="Submit"/>
# </td>
# </tr>
# <tr>
# <td height="20"></td>
# </tr>
# </table>
# <br/>
# <div align="center">
# <center>
# <table border="0" cellpadding="2" cellspacing="2" width="100%">
# <tr>
# <td align="right" valign="top" width="25%">
# <img alt="" height="130" src="https://oa.cc.iitk.ac.in:443/Oa/Jsp/Photo/10103003_0.jpg" width="130"/>
# </td>
# <td class="TableContent" nowrap="nowrap" valign="top" width="55%">
# <b>Roll No: </b>
# 																	10103003
# 																	<br/>
# <br/>
# <p>
# <b>Name: </b>
# 																		ARTI  KUMARI
# 																	</p>
# <p>
# <b>Program: </b>
# 																		MTech
# 																	</p>
# <p>
# <b>Department: </b>
# 																		CIVIL ENGG.
# 																	</p>
# <p>
# <b>Hostel Info: </b>
# 																		GH, F-306
# 																		<br/>
# </p>
# <p>
# <b> E-Mail: </b><a href="mailto:artikum@iitk.ac.in">artikum@iitk.ac.in
# 																		</a>
# </p>
# <p>
# <b> Blood Group:</b>
# 																		A+
# 																		<!--<b> Category:</b>SC<br></P>-->
# </p>
# <p>
# <b> Gender:</b>
# 																		F
# 																		<b> CountryOfOrigin:</b>
# 																		India
# 																		<br/>
# </p>
# <!--<p><b>Local Address :</b>Not Available<br>Not Available<br>
# 		Phone no:Not Available<br>Mobile no:Not Available</P>
# 		<p><b>Permanent Address :</b>SURESH CHANDRA<br>VILL.-SARIA KHURD POST-KUSAURA,DISTRICT-BASTI,Basti,U.P.,India<br>
#   		Phone no:9984814893<br>Mobile no:9984814893</P>
#                 <p><a href="Stff_Addr.jsp?typ=stud&pfno=10103003">Address</a></p>-->
# </td>
# </tr>
# </table>
# <font></font>
# </center>
# </div>
# </td>
# <td></td>
# </tr>
# </table>
# <br/>
# </td>
# </tr>
# </table>
#
#
#
# <center>
# <br/>
# <br/>
# <br/>
# <table border="0" cellpadding="2" cellspacing="0">
# <tr>
# <td colspan="10">
# <input class="submit_button" name="sbmbtn1" onclick="backfn();" type="button" value="Back"/>
# </td>
# </tr>
# </table>
# </center>
# </form>
# </body>
# </html>

# %%
print(soup)
# Out:
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Oracle JDeveloper" name="GENERATOR"/>
# <meta content="no-cache" http-equiv="cache-control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <link href="oasback.css" rel="Stylesheet" type="text/css"/>
# <title>Search_name</title>
# </head>
# <script language="javascript" type="text/javascript">
#
#  var message="";
# 			function clickIE()
# 			{
# 				if (document.all) {alert(message);return false;}
# 			}
# 			function clickNS(e)
# 			{
# 				if (document.layers||(document.getElementById&&!document.all))
# 				{
# 				  	if (e.which==2||e.which==3)
# 				  		{
# 				  			// alert(message);
# 				  			return false;
# 				  		}
# 				}
# 			}
# 				  	if (document.layers)
# 				  	{document.captureEvents(Event.MOUSEDOWN);document.onmousedown=clickNS;}
# 				  	else{document.onmouseup=clickNS;document.oncontextmenu=clickIE;}
# 			  	document.oncontextmenu=new Function("return false")
#
#
#   var s1;
#
#
#   function IsEmptyString(str)
# {
# 	nLen = str.length;
# 	for(i=0; i<nLen; ++i)
# 	{
# 		if(str.charAt(i) != " ")
# 		{
# 			return false;
# 		}
# 	}
# 	return true;
# }
#
#
# function next()
# {
#
# document.Srchfrm1.submit();
#
# }
#
# function prev(val)
# {
#
# document.Srchfrm1.recpos.value=val;
# document.Srchfrm1.submit();
# }
#
# function searchres(x){
#
#  document.Srchfrm1.numtxt.value=x;
# document.Srchfrm1.action="IITk_SrchRes_new.jsp";
# document.Srchfrm1.method="POST";
# document.Srchfrm1.submit();
#
# }
#
# </script>
# <body leftmargin="0" marginheight="0" marginwidth="0" topmargin="0">
# <p>
#
# 		</p>
# <form action="IITk_SrchStudRoll_new.jsp" method="post" name="Srchfrm1">
# <input name="k1" type="hidden" value="#ADELukNhHiN=H!_@/JyAGZyZaIWB$juKblR&amp;KFEtBFWNSo%p-#OTCX"/>
# <input name="k2" type="hidden" value="Jp=IE&amp;CFHUp_UOIXYaPQhmTCH_U/xz&amp;u@fZoiPraG-YuUEsoEBGVr$S"/>
# <input name="k3" type="hidden" value="gnYJd#NsOd-WphfNDrZ_FVDEAFGew!nRBih$@WDLSEhTXVJeHjLBSuI"/>
# <input name="numtxt" type="hidden" value="">
# <table align="center" border="0" width="100%">
# <tr>
# <td align="center" class="tablehead">
# 						Student Search
# 					</td>
# </tr>
# </table>
# <br/>
# <div align="left" class="DivContent">
#
# 				You are viewing
# 				<b>1 </b> to
# 				<b>12 </b> records out of
# 				<b>12669 </b> records
#
#
# 			</div>
# <br/>
# <table border="0" cellpadding="1" cellspacing="1" width="100%">
# <tr bgcolor="darkblue">
# <th align="left" class="TableHead">
# 						Rollno
# 					</th>
# <th align="left" class="TableHead">
# 						Name
# 					</th>
# <th align="left" class="TableHead">
# 						Department
# 					</th>
# <th align="left" class="TableHead">
# 						Program
# 					</th>
# <th align="left" class="TableHead">
# 						Blood Group
# 					</th>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud">
# <input name="sbm" type="hidden" value="Y">
# <a href="javascript:searchres('10017');">10017
# 						</a>
# </input></input></td>
# <td class="TableText">
# 						ABHISHEK ANAND YADAV
# 					</td>
# <td class="TableText">
# 						PHYSICS
# 					</td>
# <td class="TableText">
# 						MSc(Int)
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10029');">10029
# 						</a>
# </td>
# <td class="TableText">
# 						ABHISHEK PRASAD SAHOO
# 					</td>
# <td class="TableText">
# 						MATERIALS SCIENCE &amp; ENGG.
# 					</td>
# <td class="TableText">
# 						BTech
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10032');">10032
# 						</a>
# </td>
# <td class="TableText">
# 						ABHISHEK S SAYAM
# 					</td>
# <td class="TableText">
# 						COMPUTER SCIENCE &amp; ENGG.
# 					</td>
# <td class="TableText">
# 						MT(Dual)
# 					</td>
# <td class="TableText">
# 						B+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10047');">10047
# 						</a>
# </td>
# <td class="TableText">
# 						AJIT KUMAR
# 					</td>
# <td class="TableText">
# 						CIVIL ENGG.
# 					</td>
# <td class="TableText">
# 						BTech
# 					</td>
# <td class="TableText">
# 						B+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10053');">10053
# 						</a>
# </td>
# <td class="TableText">
# 						AKASH  KUMAR
# 					</td>
# <td class="TableText">
# 						CIVIL ENGG.
# 					</td>
# <td class="TableText">
# 						MT(Dual)
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10088');">10088
# 						</a>
# </td>
# <td class="TableText">
# 						ANIL  KUMAR
# 					</td>
# <td class="TableText">
# 						ELECTRICAL ENGG.
# 					</td>
# <td class="TableText">
# 						BTech
# 					</td>
# <td class="TableText">
# 						AB+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10100063');">10100063
# 						</a>
# </td>
# <td class="TableText">
# 						TARUSHIKHA  SARVESH
# 					</td>
# <td class="TableText">
# 						HUMANITIES &amp; SOC. SCIENCES
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						B+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10101061');">10101061
# 						</a>
# </td>
# <td class="TableText">
# 						ANSHUL  KHANDELWAL
# 					</td>
# <td class="TableText">
# 						AEROSPACE ENGG.
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10101065');">10101065
# 						</a>
# </td>
# <td class="TableText">
# 						SUNIL  KUMAR
# 					</td>
# <td class="TableText">
# 						AEROSPACE ENGG.
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10101066');">10101066
# 						</a>
# </td>
# <td class="TableText">
# 						DAVINDER SINGH BHOGAL
# 					</td>
# <td class="TableText">
# 						AEROSPACE ENGG.
# 					</td>
# <td class="TableText">
# 						PhD
# 					</td>
# <td class="TableText">
# 						O+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10102043');">10102043
# 						</a>
# </td>
# <td class="TableText">
# 						VINOD DIGAMBAR DAHAKE
# 					</td>
# <td class="TableText">
# 						CHEMICAL ENGG.
# 					</td>
# <td class="TableText">
# 						MTech
# 					</td>
# <td class="TableText">
# 						AB+
# 					</td>
# </tr>
# <tr>
# <td class="TableText">
# <input name="typ" type="hidden" value="stud"/>
# <input name="sbm" type="hidden" value="Y"/>
# <a href="javascript:searchres('10103003');">10103003
# 						</a>
# </td>
# <td class="TableText">
# 						ARTI  KUMARI
# 					</td>
# <td class="TableText">
# 						CIVIL ENGG.
# 					</td>
# <td class="TableText">
# 						MTech
# 					</td>
# <td class="TableText">
# 						A+
# 					</td>
# </tr>
# </table>
# <table align="right">
# <tr>
# <td>
# <input id="recpos" name="recpos" type="hidden" value="12"/>
# <input name="selstudrol" type="hidden" value=""/>
# <input name="selstuddep" type="hidden" value=""/>
# <input name="selstudnam" type="hidden" value=""/>
# <!--<font color="Darkmagenta" size=2  style="cursor:hand;" title="Next"><b>-->
# <a href="javascript:next()">NEXT</a><b></b>
# </td>
# </tr>
# </table>
# </input></form>
# </body>
# </html>

# %%
# options = Options()
# options.add_argument('--headless')

# driver = webdriver.Firefox(executable_path="/media/adi/Adi/Study/Semester_4/CS253/CS253_Project_MindHive/implementation/Driver/geckodriver-v0.30.0-linux32/geckodriver",options=options)
url = "https://oa.cc.iitk.ac.in/Oa/Jsp/OAServices/IITK_Srch.jsp?typ=stud"
# driver.get(url)
# time.sleep(2)

# payload = {'mail':'adips20'}
# s = requests.Session()
# post = s.post(url,data = payload)
# r = s.get(url)
# # soup = BeautifulSoup(driver.page_source, 'html.parser')

payload = {
    'k4': 'oa',
    'numtxt': '',
    'recpos': 0,
    'str': '',
    'selstudrol': '',
    'selstuddep': '',
    'selstudnam': '',
    'txrollno': '',
    'Dept_Stud': '',
    'selnam1': '',
    'mail': 'adips20'
}

s = requests.Session()
response = s.post(url, data=payload)
print(response.text)
# Out:
# <HTML>
# 	<HEAD>
# 		<META HTTP-EQUIV="Content-Type"
# 			CONTENT="text/html; charset=WINDOWS-1252">
# 		<META NAME="GENERATOR" CONTENT="Oracle JDeveloper">
# 		<META HTTP-EQUIV="cache-control" CONTENT="no-cache">
# 		<META HTTP-EQUIV="Pragma" CONTENT="no-cache">
# 		<META HTTP-EQUIV="Expires" CONTENT="0">
# 		<TITLE>MENU</TITLE>
# 		<LINK rel="Stylesheet" type="text/css" href="oasback.css">
#
# <script type="text/javascript">
#
#
# var message="";
# 			function clickIE()
# 			{
# 				if (document.all) {alert(message);return false;}
# 			}
# 			function clickNS(e)
# 			{
# 				if (document.layers||(document.getElementById&&!document.all))
# 				{
# 				  	if (e.which==2||e.which==3)
# 				  		{
# 				  			// alert(message);
# 				  			return false;
# 				  		}
# 				}
# 			}
# 				  	if (document.layers)
# 				  	{document.captureEvents(Event.MOUSEDOWN);document.onmousedown=clickNS;}
# 				  	else{document.onmouseup=clickNS;document.oncontextmenu=clickIE;}
# 			  	document.oncontextmenu=new Function("return false")
#
#
#
# </script>
#
#
#
# 	</BODY>
# </HTML>
